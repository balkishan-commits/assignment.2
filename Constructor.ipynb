# %% [markdown]
# ## Constructor

# %%
class Collage:
    def __init__(self):
        pass

# %%
class Collage:
    collage_name = " B K BITS"                                 # class variable
    def __init__(self, name , classes):
        self.name = name                                      # instance variable
        self.classes = classes                              # instance variable


st = Collage(name = "rohit" , classes = "second year")

# %%
st.classes

# %%
class Collage:
    collage_name = " B K BITS"                                 
    def __init__(self, name , classes):
        self.name = name                                      
        self.classes = classes                           

    def account(self):
        print(f"my name is {name} and my class{classes}")
        


st = Collage(name = "rohit" , classes = "second year")

# %%
class Vehicles:
    vehicle_variety = car
