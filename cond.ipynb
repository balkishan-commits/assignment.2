# %% [markdown]
# class Classname:
#    pass

# %%
class college:
    pass

# %%
class LastName:
    pass

# %%
class Collage:
    collage_name = "B K BITS"
    college_add = "pilani"
    collage_sp = 42

    student = Collage()

# %%
student.collage_name

# %%
student.college_add

# %%
class College:
    clss = "second year"
    collage_name = "BK BITS"
    collage_sp = 42

    def display(a,b):
    print(a.clss)
    print(a.collage_name)
    print(a.collage_sp)


clg = Collage()

# %%
clg.diaplay()

# %%
class Company:
    company_name = "rangers pvt ltd"
    company_add  = "jaipur"

class Developer(Company):
    developer_name = "Rohit"

dev = Developer()

# %%
dev.company_name

# %%
dev.company_add

# %%
class Collage:
