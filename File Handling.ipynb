# %% [markdown]
# ## File Handling

# %%
file = open('demo.txt',"r")

# %%
file.read()

# %%
file.close()

# %%
file.read lines()

# %%
# write mode

file = open("intro.txt","w")
file.write("hello my name is balkishan")
file.close()

# %%
file = open ("my intro.txt", "a")
file.write("hello sir my name is balkishan")
file.close()

# %%
file = open(")
